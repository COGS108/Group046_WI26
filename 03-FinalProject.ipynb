# %% [markdown]
# # COGS 108 - How environmental Conditons Affect Attendance in Yosemite National Park
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [ X ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# This study examines whether environmental conditions have an influence/correlation to the visitation patterns at Yosemite National Park. Specifically, we are investigating the extent to which daily variation in the air quality index (AQI) is associated with changes in visitor counts, while also controlling for other confounding variables such as, daily maximum temperature and total precipitation. Understanding these relationships are important because environment conditions can very easily affect visitor safety, the  outdoor recreational experience, as well as park management and maintenance.
#
#
# To address this question, we decided to combine multiple datasets covering Yosemite National park from approximately 1990 to 2025. These datasets include, daily air quality data from the U.S. Environmental Protection Agency (EPA), visitor count data from the National Park Service, and weather observations from the National Oceanic and Atmospheric Administration (NOAA). By integrating these sources, we are able to analyze how variations in air quality and weather conditions correspond with changes in visitor attendance over time.
#
#
# Our results suggest that poorer environmental conditions, such as higher AQI levels, extreme weather, and heavy precipitation, are generally associated with slight decreases in visitor counts. However because the observed relationships don't have significant results, we are unable to claim a direct correlation between the variables is true. This tells us that while environmental conditions can influence visitation decisions, they are not the primary reasons behind the park's visitor attendance. Nonetheless, the findings are still in favor of our hypothesis and due to the broadness of variables used, this research can be studied within other national parks in the United States, as well as neighboring countries.

# %% [markdown]
# ## Authors
#
# Team list and credits:
# - Katelyn Yap: Conceptualization, Data set 1, Writing - code cleanup; Revision
# - Vy Nguyen: Ethics Revision, Project Timeline Proposal, Dataset 3
# - Ria Parikh: Dataset 4, Writing - code cleanup; Ethics; Team expectations; Abstract; Revision
# - Laird Fowle: Dataset 2, Writing - code cleanup
# - Cindy Tao: Dataset 5, Writing - code cleanup; Discussion & conclusion

# %% [markdown]
# ## Research Question

# %% [markdown]
# To what extent does variation in daily Air Quality Index (AQI), as measured by the U.S. Environmental Protection Agency (EPA), explain variation in daily visitor trailhead sensor counts in Yosemite National Park between 1990 and 2025, controlling for daily maximum temperature and total precipitation?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Outdoor recreation in national parks is influenced by environmental conditions that affect both visitor safety and overall experience. In the western United States, air quality has become an increasingly important factor due to wildfire smoke and regional pollution. The U.S. Environmental Protection Agency’s Air Quality Index (AQI) is a standardized measure used to communicate the health risks associated with air pollution and to inform the public about outdoor activity safety.
#
# Because many national park activities involve extended outdoor physical activity, changes in air quality may affect visitors’ decisions about whether and when to visit. Understanding how air quality relates to park visitation is therefore relevant for park management, public health communication, and planning in highly visited parks such as Yosemite National Park.
#
# Previous research has established a clear connection between environmental conditions and tourism behavior. Buckley (2011) reviews existing literature on tourism and the environment and finds that weather, climate variability, and environmental quality consistently influence visitation patterns in natural areas. <a href="#ref1">1</a> The review also notes that visitor responses differ depending on the type of destination and visitor motivations, suggesting that environmental effects may not be uniform across parks. However, Buckley’s work is conceptual and broad in scope, leaving open questions about how specific environmental indicators, such as AQI, influence visitation at individual parks.
#
# Empirical studies provide further evidence that air pollution affects park visitation. Keiser, Lade, and Rudik (2018) examine monthly visitation data from 33 U.S. national parks and find that higher ozone pollution levels are associated with reduced visitation, even after accounting for weather, seasonality, and park-specific differences. <a href="#ref2">2</a> While this study demonstrates that air pollution can influence park use at a national scale, it relies on monthly averages and does not isolate park-specific daily behavioral responses. In addition, although Yosemite is included in their broader sample, the study does not focus specifically on Yosemite’s unique visitation patterns or wildfire-related air quality variability.
#
# More recent work has used alternative data sources to study visitation patterns at finer time scales. Minehart et al. (2025) analyze weekly visitation to parks and protected areas in the Pacific Northwest using anonymized mobile device data, examining the effects of temperature, precipitation, AQI, and particulate matter (PM2.5). <a href="#ref3">3</a> The authors find that higher levels of PM2.5 are generally associated with lower visitation, while the relationship between AQI and visitation varies across different types of parks. However, their analysis aggregates across multiple parks and regions, making it difficult to determine how daily air quality fluctuations affect a single, high-profile destination over a long time horizon.
#
# Together, these studies suggest that environmental quality and weather conditions play an important role in shaping park visitation, while also highlighting important gaps in the literature. Much of the prior work relies on monthly or weekly data and emphasizes cross-park comparisons rather than park-specific, daily analysis. Furthermore, limited attention has been given to how short-term variation in AQI influences visitation in an iconic and highly visited park such as Yosemite, particularly over multiple decades that include periods of increasing wildfire activity.
#
# The present project addresses these gaps by examining whether daily variation in AQI predicts daily visitation to Yosemite National Park from 1979 to 2023, while controlling for daily maximum temperature and total precipitation. By focusing on a single park and using daily data, this study aims to capture short-term behavioral responses to air quality conditions that may be obscured in broader, aggregated analyses. This park-specific approach provides clearer insight into how air pollution influences visitation decisions in one of the most prominent national parks in the United States.
#
# 1. <a name="ref1"></a> Buckley, R. (2011). Tourism and environment. Annual Review of Environment and Resources, 36, 397–416. https://www.annualreviews.org/content/journals/10.1146/annurev-environ-041210-132637
#
# 2. <a name="ref2"></a> Keiser, D., Lade, G. E., & Rudik, I. (2018). Air pollution and visitation at U.S. national parks. Science Advances, 4(7). https://pmc.ncbi.nlm.nih.gov/articles/PMC6051738/
#
# 3. <a name="ref3"></a> Minehart, J., et al. (2025). The mountains are calling, but will visitors go? Modeling the effect of weather and air quality on visitation to Pacific Northwest parks and protected areas using mobile device data. https://www.researchgate.net/publication/390630027_The_mountains_are_calling_but_will_visitors_go_Modeling_the_effect_of_weather_and_air_quality_on_visitation_to_Pacific_Northwest_parks_and_protected_areas_using_mobile_device_data

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that there is a statistically significant negative correlation between the daily Air Quality Index (AQI) and daily visitor trailhead sensor counts in Yosemite National Park from 1999–2025. Specifically, we predict that as the AQI value increases (indicating worse air quality), the number of daily trail users will decrease, and this relationship will continue even after controlling for daily maximum temperature and total precipitation.

# %% [markdown]
# ## Data

# %% [markdown]
# ## Data overview
# Our first dataset is the EPA Air Quality Index (AQI) data for Mariposa County, our second dataset is the Yosemite National Park visitation dataset from the National Park Service, our third dataset is NOAA Daily Maximum Temperature (TMAX), and our fourth dataset is NOAA Total Precipitation (PRCP). We plan to combine the datasets by analyzing each one separately, analyzing AQI for air quality effects, TMAX and PRCP for weather-related effects, and visitation counts for park attendance, and then comparing the results to evaluate how environmental conditions influence daily visitor patterns in Yosemite National Park.
#
# ## Dataset #1: EPA Daily Air Quality Index
#
# - **Dataset name:**  EPA Daily Air Quality Index for Mariposa County, CA
# - **Link to the dataset:** [EPA Daily AQI Data](https://www.epa.gov/outdoor-air-quality-data/download-daily-data)
# - **Number of observations:** ~12,000 daily records (1990–2025)
# - **Number of variables:** 4 core variables used in the analysis
#
# This dataset contains daily air quality measurements reported by the U.S. Environmental Protection Agency (EPA). Each row represents the **Air Quality Index (AQI)** recorded on a single day at a monitoring station in **Mariposa County, California**, the county containing Yosemite National Park.
#
# The AQI is a standardized measure used by the EPA to communicate how polluted the air currently is or how polluted it is expected to become. Higher AQI values indicate worse air quality and greater potential health risks. Because Yosemite is a major outdoor recreation destination, poor air quality may influence visitation patterns by affecting visitor comfort and safety.
#
# The dataset spans approximately **34 years (1990–2025)**, which allows us to analyze both long-term trends and short-term daily variation in air quality conditions around Yosemite.
#
# ---
#
# ### Key Variables
#
# | Variable | Type | Description |
# |---------|------|-------------|
# | Date | Datetime | The calendar date of the AQI measurement, enabling time-series analysis. |
# | AQI | Numeric | The Air Quality Index value for the day. Higher values indicate worse air quality. |
# | Category | Categorical | EPA air quality category (Good, Moderate, Unhealthy for Sensitive Groups, Unhealthy, etc.). |
# | Defining Parameter | Categorical | The pollutant responsible for the AQI level (e.g., ozone, particulate matter). |
#
# ---
#
# ### Important Metrics
#
# **Air Quality Index (AQI)**
# AQI is the central variable used to measure overall air pollution levels. The index ranges from 0 to 500, where higher values correspond to poorer air quality and greater potential health risks for visitors.
#
# **Air Quality Category**
# The EPA groups AQI values into health-based categories such as *Good*, *Moderate*, and *Unhealthy*. This categorical representation helps interpret pollution levels more easily.
#
# **Defining Pollutant**
# This variable indicates which pollutant contributed most to the AQI value on a given day. In the Yosemite region, ozone and particulate matter are often the primary contributors, particularly during wildfire seasons.
#
# ---
#
# ### Data Wrangling Summary
#
# The dataset was downloaded as a CSV file containing daily air quality observations. The following preprocessing steps were applied:
#
# - Converted the **Date column** to datetime format for time-based analysis.
# - Checked AQI values to ensure they were numeric and within the expected EPA range.
# - Removed duplicate or malformed records.
# - Filtered observations to include **Mariposa County monitoring stations only** to maintain geographic consistency with Yosemite-related analysis.
# - Aligned dates with other datasets used in the project.
#
# ---
#
# ### Shortcomings
#
# - **Sparse historical coverage before 1990:** Earlier monitoring records are inconsistent or missing.
# - **Spatial mismatch:** The monitoring station represents conditions in Mariposa County and may not perfectly reflect air quality at remote areas of Yosemite such as high-elevation trails.
# - **Missing monitoring days:** Some days have no recorded measurements and must be treated as genuinely missing data.
# - **Limited pollutant-level analysis:** Although the dataset includes the defining pollutant, this project primarily focuses on overall AQI levels.

# %%
# Setup code -- Run only once after cloning!!!
# Downloads raw AQI CSV from GitHub repository

# %pip install requests

import requests
import os

url = "https://raw.githubusercontent.com/COGS108/Group046_WI26/master/data/00-raw/aqi_data_1990_2025.csv"

os.makedirs("data/00-raw", exist_ok=True)
response = requests.get(url)

with open("data/00-raw/aqi_data_1990_2025.csv", "wb") as f:
    f.write(response.content)

print("Raw AQI data downloaded successfully.")
# Out:
# ...
# Raw AQI data downloaded successfully.

# %%
import pandas as pd
import os

# load dataset
url = "https://raw.githubusercontent.com/COGS108/Group046_WI26/master/data/00-raw/aqi_data_1990_2025.csv"
aqi_raw = pd.read_csv(url)

# clean column names
aqi_raw.columns = aqi_raw.columns.str.strip().str.lower()

# filter Mariposa County
aqi = aqi_raw[aqi_raw['county'] == 'Mariposa'].copy()

# rename important columns
aqi = aqi.rename(columns={
    "date": "Date",
    "county": "County",
    "state": "State",
    "daily max 8-hour ozone concentration": "Ozone 8hr Max",
    "daily aqi value": "Daily AQI",
    "local site name": "Site Name",
    "site latitude": "Latitude",
    "site longitude": "Longitude"
})

# parse date and extract year/month
aqi["Date"] = pd.to_datetime(aqi["Date"], errors="coerce")
aqi = aqi.dropna(subset=["Date"])
aqi["Year"] = aqi["Date"].dt.year
aqi["Month"] = aqi["Date"].dt.month

# convert pollutant columns to numeric
pollutant_cols = ["Ozone 8hr Max", "Daily AQI"]
for col in pollutant_cols:
    aqi[col] = pd.to_numeric(aqi[col], errors="coerce")

# aggregate to monthly means (to match visitation + precip/TMAX data)
aqi_monthly = (
    aqi.groupby(["Year", "Month"])[pollutant_cols]
    .mean()
    .reset_index()
    .sort_values(["Year", "Month"])
    .reset_index(drop=True)
)

print("Final AQI dataset shape:", aqi_monthly.shape)
print("Year range:", aqi_monthly["Year"].min(), "-", aqi_monthly["Year"].max())

# save cleaned dataset
os.makedirs("data/02-processed", exist_ok=True)
aqi_monthly.to_csv("data/02-processed/mariposa_aqi.csv", index=False)

# print("Clean AQI data saved.")
# Out:
# Final AQI dataset shape: (432, 4)
# Year range: 1990 - 2025

# %% [markdown]
# ## Dataset #2: Yosemite National Park Visitation Counts
#
#   - **Dataset name:** Yosemite National Park Monthly Visitor Statistics (NPS)
#   - **Link to the dataset:** [NPS Visitor Data](<https://irma.nps.gov/Stats/SSRSReports/Park%20Specific%20Reports/Recreation%20Visitors%20By%20Month%20(1979%20-%20Last%20Calendar%20Year)?Park=YOSE>)
#   - **Number of observations:** 564 (1979–2025)
#   - **Number of variables:** 2 primary variables
#
# This dataset contains **monthly visitation counts for Yosemite National Park**, provided by the U.S. National Park Service (NPS). Each record represents the total number of visitors entering the park during a given month. The counts are collected through entrance stations and ranger monitoring at Yosemite’s five official park entrances.
#
# This dataset provides the **dependent variable for our analysis**. Our research question examines how environmental conditions such as air quality and weather influence park visitation. Therefore, visitor counts are used to measure how attendance changes over time in response to these environmental factors.
#
# ---
#
# ### Key Variables
#
# | Variable | Type | Description |
# |---------|------|-------------|
# | Date | Datetime | The year and month of the recorded visitation count |
# | Visitor Count | Numeric | Total number of visitors entering Yosemite during that month |
#
# ---
#
# ### Important Metrics
#
# **Visitor Count**
# This variable represents the total number of visitors entering Yosemite National Park during a given month. It serves as the main outcome variable used to measure park attendance trends.
#
# **Seasonal Variation**
# Visitor numbers vary strongly by season, with summer months typically seeing the highest attendance. Seasonal patterns must therefore be considered when interpreting environmental effects.
#
# ---
#
# ### Data Wrangling Summary
#
# The visitation data was downloaded from the National Park Service statistics portal and cleaned before analysis.
#
# Cleaning steps included:
#
# - Removing non-data header rows from the raw file
# - Dropping unnecessary columns
# - Parsing the date column into a usable datetime format
# - Renaming columns for clarity
# - Converting visitor counts to numeric values
#
# The cleaned dataset was then saved for further analysis and merged with the environmental datasets.
#
# ---
#
# ### Shortcomings
#
# - **Monthly resolution:** The data is only available at a monthly level rather than daily, which limits the ability to observe short-term behavioral responses.
# - **Entrance-based counting:** Visitor counts only represent people entering through official park entrances.
# - **Limited sample size:** With 564 observations, statistical power may be lower compared to daily datasets.

# %%
import pandas as pd
import io
import requests

#load data
url = "https://raw.githubusercontent.com/COGS108/Group046_WI26/72efcfcfe6ea229d895a0e93db5f02fc74ef297c/data/00-raw/Recreation%20Visitors%20By%20Month%20(1979%20-%20Last%20Calendar%20Year).csv"
s = requests.get(url).content

#data cleaning (getting rid of non-data rows and columns)
#remove "LabelName" and "Yosemite NP" lines and "Textbox5" column
df = pd.read_csv(io.StringIO(s.decode('utf-8')), skiprows=2)
df = df.drop(columns=['Textbox5'])

#wrangle columns
month_cols = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
for col in month_cols:
    df[col] = df[col].astype(str).str.replace(',', '').replace('nan', '0')
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# switch to reading lengthwise instead of widthwise
df_tidy = df.melt(id_vars=['Year'],
                  value_vars=month_cols,
                  var_name='Month',
                  value_name='Visitors')

month_map = {'JAN':1, 'FEB':2, 'MAR':3, 'APR':4, 'MAY':5, 'JUN':6,
             'JUL':7, 'AUG':8, 'SEP':9, 'OCT':10, 'NOV':11, 'DEC':12}
df_tidy['Month_Num'] = df_tidy['Month'].map(month_map)
df_tidy['Date'] = pd.to_datetime(df_tidy[['Year']].assign(Month=df_tidy['Month_Num'], Day=1))
#exclude 2026
df_tidy = df_tidy[df_tidy['Year'] != 2026].copy()

# 1. Size of dataset
print(f'Shape: {df_tidy.shape}')
print(f'Date range: {df_tidy["Date"].min().date()} to {df_tidy["Date"].max().date()}')

# 2. Tidiness check
print(f'\nDuplicate month/year combos: {df_tidy[["Year", "Month"]].duplicated().sum()}')

# 3. Missingness
print('\nMissing values per column:')
print(df_tidy.isnull().sum())

# 4. Missing calendar months
# Check for gaps between 1979 and the most recent year
expected_months = pd.date_range(start='1979-01-01', end=df_tidy['Date'].max(), freq='MS')
missing_months = expected_months.difference(df_tidy['Date'])
print(f'\nCalendar months with no visitor data: {len(missing_months)}')
if len(missing_months) > 0:
    print(f'Missing periods: {missing_months}')

# 5. Outliers
print('\nVisitor count summary statistics:')
print(df_tidy['Visitors'].describe())
# outlier: exceptionally low month (<50k visitors)
low_traffic = df_tidy[df_tidy['Visitors'] < 50000]
print(f'\nMonths with < 50,000 Visitors: {len(low_traffic)}')
print(low_traffic[['Date', 'Visitors']])

# 6. Seasonality breakdown
avg_by_month = df_tidy.groupby('Month')['Visitors'].mean().sort_values(ascending=False)
print('\nAverage Visitors by Month (Historical):')
print(avg_by_month)

# 7. Save cleaned file
os.makedirs('data/02-processed', exist_ok=True)
df_tidy.to_csv('data/02-processed/yosemite_visitors_cleaned.csv', index=False)
print('\nSaved to data/02-processed/yosemite_visitors_cleaned.csv')

#sort values
df_tidy = df_tidy.sort_values('Date').reset_index(drop=True)

print(df_tidy.head())
# Out:
# Shape: (564, 5)
# Date range: 1979-01-01 to 2025-12-01
#
# Duplicate month/year combos: 0
#
# Missing values per column:
# Year         0
# Month        0
# Visitors     0
# Month_Num    0
# Date         0
# dtype: int64
#
# Calendar months with no visitor data: 0
#
# Visitor count summary statistics:
# count       564.000000
# mean     290973.824468
# std      179421.337020
# min           0.000000
# 25%      128137.750000
# 50%      250209.500000
# 75%      437177.250000
# max      780728.000000
# Name: Visitors, dtype: float64
#
# Months with < 50,000 Visitors: 4
#           Date  Visitors
# 29  1997-01-01     12520
# 99  2023-03-01     25005
# 150 2020-04-01         0
# 198 2020-05-01         0
#
# Average Visitors by Month (Historical):
# Month
# AUG    562475.531915
# JUL    546672.957447
# JUN    447375.872340
# SEP    438603.340426
# MAY    335809.468085
# OCT    324009.382979
# APR    209491.425532
# NOV    159619.617021
# MAR    138245.957447
# DEC    118335.744681
# ...

# %% [markdown]
# ## Dataset #3: NOAA Daily Weather Data – Yosemite National Park
#
# - **Dataset name:** NOAA Global Historical Climatology Network Daily (GHCND)
#
# - **Link to the dataset:** [NOAA GHCND Yosemite](https://www.ncei.noaa.gov/cdo-web/datasets/GHCND/stations/GHCND:USC00049855/detail)
# - **Number of observations:** ~12,418 daily records (1990–2024)
# - **Number of variables:** 3 primary variables used
#
# This dataset contains **daily weather observations for Yosemite National Park** collected by the National Oceanic and Atmospheric Administration (NOAA). The data comes from a weather monitoring station located at Yosemite Park Headquarters.
#
# Weather conditions are included in the analysis because environmental factors such as temperature and precipitation may influence visitor behavior and park accessibility.
#
# ---
#
# ### Key Variables
#
# | Variable | Type | Description |
# |---------|------|-------------|
# | DATE | Datetime | The date of the weather observation |
# | TMAX | Numeric | Maximum daily temperature |
# | PRCP | Numeric | Total daily precipitation |
#
# ---
#
# ### Important Metrics
#
# **Maximum Daily Temperature (TMAX)**
# Daily maximum temperature captures how warm conditions were on a given day. Extreme temperatures may discourage visitors or make outdoor activities less comfortable.
#
# **Daily Precipitation (PRCP)**
# Precipitation measures rainfall or snowfall occurring on a given day. Heavy precipitation may reduce visitation due to travel difficulties or poor hiking conditions.
#
# ---
#
# ### Data Wrangling Summary
#
# The NOAA dataset was downloaded as part of the Global Historical Climatology Network Daily dataset.
#
# Preprocessing steps included:
#
# - Cleaning column names and selecting relevant variables
# - Converting date values to datetime format
# - Converting temperature and precipitation values to numeric types
# - Removing unrealistic or erroneous measurements
# - Checking for missing values and duplicates
#
# The cleaned weather dataset was then stored for later merging with the AQI and visitation datasets.
#
# ---
#
# ### Shortcomings
#
# - **Spatial mismatch:** The monitoring station is located around 4,000 feet elevation, while some Yosemite trailheads exceed 8,600 feet.
# - **Missing observations:** Some days may be missing due to instrument outages or recording gaps.
# - **Local variability:** Weather conditions can vary significantly across different areas of Yosemite.

# %% [markdown]
# ### Yosemite National Park Visitation Counts - Yosemite, CA
# The Yosemite visitation dataset provided by the National Park Service (NPS) provides us monthly visitation data for the park. This data spans 1979-2025 and contains 564 points of park visistation counts. This data provides our experiment with its key dependent variable, visitation count. The counts are seperated by year and month, respectively. This data is collected through counting park admittances, as handled by onsite rangers and other staff at Yosemite's 5 entrance gates.
#
# The main concern with this dataset is the lack of daily visitation data. The NPS only provides data at a month level, meaning that trends will need to be observed through a longer time frame in order for causation to be apparent. The other concern is an insufficient number of data points. In order to develop a proper statistical inference, the sample size needs to be adequate, and we are unsure if 564 observations will be sufficient to develop a proper statistical inference.

# %%
import pandas as pd
import os
from IPython.display import display

# load weather data (Yosemite)
path = "https://raw.githubusercontent.com/COGS108/Group046_WI26/vy/data/00-raw/yosemite_weather_1990_2024.csv"
weather = pd.read_csv(path)

# fix DATE column to datetime
weather['DATE'] = pd.to_datetime(weather['DATE'], errors='coerce')

# make sure important columns are numeric
weather['TMAX'] = pd.to_numeric(weather['TMAX'], errors='coerce')
weather['PRCP'] = pd.to_numeric(weather['PRCP'], errors='coerce')

# remove invalid NOAA values
weather.loc[weather['TMAX'] < -50, 'TMAX'] = pd.NA
weather.loc[weather['PRCP'] < 0, 'PRCP'] = pd.NA

# remove unrealistic temperature values
weather.loc[(weather['TMAX'] > 115) | (weather['TMAX'] < -30), 'TMAX'] = pd.NA

# drop missing values after cleaning
weather = weather.dropna(subset=['DATE', 'TMAX', 'PRCP'])

# dataset before/after idea (kept simple)
print("after cleaning:")
display(pd.DataFrame({
    "rows": [weather.shape[0]],
    "columns": [weather.shape[1]]
}))

print("date range:")
display(pd.DataFrame({
    "start": [weather["DATE"].min()],
    "end": [weather["DATE"].max()]
}))

print("duplicate dates:")
display(pd.DataFrame({
    "count": [weather["DATE"].duplicated().sum()]
}))

print("missing values:")
display(weather[['TMAX', 'PRCP']].isnull().sum().to_frame(name="missing"))

print("summary stats:")
display(weather[['TMAX', 'PRCP']].describe())

# remove duplicate dates + sort
weather = (
    weather
    .drop_duplicates(subset=['DATE'])
    .sort_values('DATE')
    .reset_index(drop=True)
)

# save cleaned dataset
os.makedirs('data/02-processed', exist_ok=True)
weather.to_csv('data/02-processed/yosemite_weather_clean.csv', index=False)

print("saved cleaned weather data")
# Out:
# after cleaning:
#    rows  columns
# 0  9748        5
# date range:
#        start        end
# 0 1990-01-01 2023-11-29
# duplicate dates:
#    count
# 0      0
# missing values:
#       missing
# TMAX        0
# PRCP        0
# summary stats:
#               TMAX         PRCP
# count  9748.000000  9748.000000
# mean     67.823861     0.100674
# std      17.453335     0.353031
# min      21.000000     0.000000
# 25%      53.000000     0.000000
# 50%      68.000000     0.000000
# 75%      84.000000     0.000000
# max     104.000000     5.430000
# saved cleaned weather data

# %% [markdown]
# ## Dataset #4: NOAA Total Precipitation Data – Yosemite National Park
#
#   - **Dataset name:** NOAA Daily Precipitation Records (GHCND Station Data)
#   - **Link to the dataset:** [NOAA Yosemite Precipitation](https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND/stations/GHCND:USC00049855/detail)
#   - **Number of observations:** ~11,257 daily records (1990–2025)
#   - **Number of variables:** 6
#
# This dataset provides **daily precipitation measurements recorded at Yosemite Park Headquarters**. Precipitation includes rainfall, snowfall, and other forms of moisture that accumulate throughout the day.
#
# Precipitation is important for our study because heavy rainfall or snow can affect road conditions, trail safety, and visitor travel decisions.
#
# ---
#
# ### Key Variables
#
# | Variable | Type | Description |
# |---------|------|-------------|
# | Station | Categorical | Weather station identifier |
# | Station Name | Categorical | Name of the monitoring station |
# | Date | Datetime | Date of the observation |
# | PRCP | Numeric | Total daily precipitation |
# | MDPR | Numeric | Maximum daily precipitation |
# | DAPR | Numeric | Number of days with precipitation |
#
# ---
#
# ### Important Metrics
#
# **Total Daily Precipitation (PRCP)**
# This variable measures how much precipitation occurred on a given day. High precipitation levels may discourage visitors or make park travel conditions more difficult.
#
# **Annual Precipitation Trends**
# Long-term trends in precipitation help evaluate climate variability and potential environmental changes affecting Yosemite.
#
# ---
#
# ### Data Wrangling Summary
#
# The precipitation dataset was cleaned through the following steps:
#
# - Standardizing column names
# - Renaming variables for readability
# - Converting the date column to datetime format
# - Converting precipitation measurements to numeric values
# - Removing negative or invalid precipitation values
# - Removing duplicate date entries
#
# The cleaned dataset was saved as `yosemite_precipitation.csv` for later analysis.
#
# ---
#
# ### Shortcomings
#
# - **Missing observations:** Some daily precipitation values may be missing or incomplete.
# - **Instrument changes:** Weather monitoring equipment may have changed over time.
# - **Limited spatial coverage:** Data comes from a single weather station within the park.
# - **Measurement ambiguity:** Trace precipitation amounts may sometimes be recorded inconsistently.

# %%
import pandas as pd
import os

# Load raw precipitation data
path = "https://raw.githubusercontent.com/COGS108/Group046_WI26/ria/data/00-raw/raw_precipitation_data.csv"
df = pd.read_csv(path)

# 1. Clean column names
df.columns = df.columns.str.strip()

# 2. Filter Yosemite data
precip = df[df['STATION_NAME'].str.contains('YOSEMITE', na=False)].copy()

# 3. Rename + parse date
precip['Date'] = pd.to_datetime(precip['DATE'], errors='coerce')
precip = precip.rename(columns={'PRCP': 'Precipitation'})

# 4. Basic dataset info
print("Shape:", precip.shape)
print("Date range:", precip['Date'].min(), "to", precip['Date'].max())

# 5. Check duplicates
print("\nDuplicate dates:", precip['Date'].duplicated().sum())

# 6. Missing values
print("\nMissing values per column:")
print(precip.isnull().sum())

# 7. Missing calendar days
full_range = pd.date_range(start=precip['Date'].min(), end=precip['Date'].max())
missing_days = full_range.difference(precip['Date'])

print("\nCalendar days with no precipitation reading:", len(missing_days))
print("Missing days are dropped (not filled), since no record ≠ zero precipitation.")

# 8. Summary statistics
print("\nPrecipitation summary statistics:")
print(precip['Precipitation'].describe())

# 9. Outliers (extreme precipitation days)
outliers = precip[precip['Precipitation'] > 100]
print("\nExtreme precipitation days:", len(outliers))

# 10. Monthly totals (for trends)
precip['Month'] = precip['Date'].dt.to_period('M')
monthly_totals = precip.groupby('Month')['Precipitation'].sum()

print("\nTop 10 wettest months:")
print(monthly_totals.sort_values(ascending=False).head(10))

# 11. Save cleaned dataset
os.makedirs('data/02-processed', exist_ok=True)
precip.to_csv('data/02-processed/yosemite_precipitation.csv', index=False)

print("\nSaved to data/02-processed/yosemite_precipitation.csv")
# Out:
# Shape: (11257, 7)
# Date range: 1970-01-01 00:00:00.019900101 to 1970-01-01 00:00:00.020251231
#
# Duplicate dates: 0
#
# Missing values per column:
# STATION          0
# STATION_NAME     0
# DATE             0
# MDPR             0
# DAPR             0
# Precipitation    0
# Date             0
# dtype: int64
#
# Calendar days with no precipitation reading: 0
# Missing days are dropped (not filled), since no record ≠ zero precipitation.
#
# Precipitation summary statistics:
# count    11257.000000
# mean       -82.512430
# std        905.125404
# min      -9999.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          5.430000
# Name: Precipitation, dtype: float64
#
# Extreme precipitation days: 0
#
# Top 10 wettest months:
# Month
# 1970-01   -928842.43
# Freq: M, Name: Precipitation, dtype: float64
#
# Saved to data/02-processed/yosemite_precipitation.csv

# %% [markdown]
# ## Results
# ### Exploratory Data Analysis
#
# We load the fully cleaned datasets from `data/02-processed/` and conduct exploratory data analysis (EDA) to examine how environmental conditions relate to visitor patterns in Yosemite National Park.
#
# Our analysis focuses on four key components:
# 1. Air quality trends over time (using ozone as a proxy for AQI)
# 2. Visitor patterns and seasonal variation
# 3. Temperature distributions and long-term trends
# 4. Precipitation variability and extreme events
#
# By analyzing each dataset individually, we identify key patterns and trends that will inform our later comparisons and statistical analysis.

# %% [markdown]
# ### 1. Air Quality Trends (Ozone)
#
# We analyze air quality in Mariposa County using ozone levels as our primary metric. Ozone is consistently recorded across all years and is a major contributor to overall AQI in the Yosemite region, making it a reliable measure for long-term analysis.
#
# To examine changes over time, we aggregate daily ozone readings to monthly means, then compute annual means for visualization. We plot these annual means with a linear trend line to capture both year-to-year variability and any overall trend.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# load processed data
aqi = pd.read_csv('data/02-processed/mariposa_aqi.csv')

# ensure year is integer
aqi['Year'] = pd.to_numeric(aqi['Year'], errors='coerce')
aqi = aqi.dropna(subset=['Year'])
aqi['Year'] = aqi['Year'].astype(int)

# aggregate monthly data to annual means for trend visualization
ozone = (
    aqi[['Year', 'Ozone 8hr Max']].dropna()
    .groupby('Year')['Ozone 8hr Max']
    .mean()
    .reset_index()
)

# fit linear trend line
z = np.polyfit(ozone['Year'], ozone['Ozone 8hr Max'], 1)
p = np.poly1d(z)

# create figure
fig, ax = plt.subplots(figsize=(12, 5))

# scatter plot
ax.scatter(
    ozone['Year'],
    ozone['Ozone 8hr Max'],
    s=60,
    zorder=3,
    label='Annual Mean Ozone 8hr Max'
)

# trend line
x_range = np.linspace(ozone['Year'].min(), ozone['Year'].max(), 200)
ax.plot(
    x_range,
    p(x_range),
    linestyle='--',
    linewidth=2,
    label=f'Trend (slope={z[0]:.4f} ppm/year)'
)

# annotate worst year
worst = ozone.loc[ozone['Ozone 8hr Max'].idxmax()]
ax.annotate(
    f"{int(worst['Year'])}\n({worst['Ozone 8hr Max']:.3f} ppm)",
    xy=(worst['Year'], worst['Ozone 8hr Max']),
    xytext=(worst['Year'] - 3, worst['Ozone 8hr Max'] + 0.005),
    arrowprops=dict(arrowstyle='->')
)

# labels and formatting
ax.set_xlabel('Year')
ax.set_ylabel('Ozone 8hr Max (ppm)')
ax.set_title('Annual Mean Ozone Levels - Mariposa County, CA (1990–2025)',
             fontweight='bold')
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.legend()

plt.tight_layout()
plt.savefig('data/02-processed/ozone_trend.png', dpi=150, bbox_inches='tight')
plt.show()

# print summary
best = ozone.loc[ozone['Ozone 8hr Max'].idxmin()]

print(f"Overall trend: {z[0]:+.4f} ppm per year")
print(f"Worst year:  {int(worst['Year'])} ({worst['Ozone 8hr Max']:.3f} ppm)")
print(f"Best year:   {int(best['Year'])} ({best['Ozone 8hr Max']:.3f} ppm)")
# Out:
# Overall trend: -0.0000 ppm per year
# Worst year:  1999 (0.057 ppm)
# Best year:   1993 (0.042 ppm)

# %% [markdown]
# The trend line slope reflects the average annual change in ozone levels across the
# study period. A positive slope indicates worsening air quality over time, consistent with
# increased heat and wildfire activity in the Sierra Nevada. Spike years are expected to
# align with well-documented major fire and heat seasons in the region. Because PM
# 2.5
# data was unavailable for Mariposa County in this dataset, ozone serves as the primary
# air quality proxy, it is independently regulated by the EPA and directly relevant to
# outdoor recreation decisions. This trend provides the foundational environmental
# context for examining how air quality
# variation relates to visitor counts in Yosemite!

# %% [markdown]
# ### 2. Visitor Patterns
#
# We use Yosemite National Park visitation data from the National Park Service (NPS) as our primary measure of visitor behavior. This dataset contains monthly visitation counts from 1979 to 2025, totaling 564 observations.
#
# This dataset serves as our key dependent variable, representing how park attendance changes over time. Because the data is recorded monthly, it allows us to analyze long-term trends and seasonal patterns in visitation.
#
# One limitation of this dataset is that visitation is only recorded at the monthly level rather than daily. This reduces the resolution of the data and means short-term fluctuations cannot be directly observed.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

#import data
df = pd.read_csv(('data/02-processed/yosemite_visitors_cleaned.csv'), index_col='Date', parse_dates=True)

df['Month'] = df.index.month_name()

#plot data
plt.figure(figsize=(12, 6))
sns.boxplot(x='Month', y='Visitors', data=df,
            order=['January', 'February', 'March', 'April', 'May', 'June',
                   'July', 'August', 'September', 'October', 'November', 'December'])
plt.title('Distribution of Visitors by Month (1979-2025)')
plt.xticks(rotation=45)
plt.show()

#---------------
# Load and prepare data
df = pd.read_csv('data/02-processed/yosemite_visitors_cleaned.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date').set_index('Date')

# Global Variance and Distribution Stats
global_stats = df['Visitors'].agg(['mean', 'median', 'var', 'std', 'skew'])

# Monthly Volatility, Grouping by month to see seasonal variance
# Coeff of var CV = std / mean
monthly_stats = df.groupby(df.index.month_name())['Visitors'].agg(['mean', 'var', 'std'])
monthly_stats['CV'] = monthly_stats['std'] / monthly_stats['mean']

# 3.variation by decade
df['Decade'] = (df.index.year // 10) * 10
decade_stats = df.groupby('Decade')['Visitors'].agg(['mean', 'var', 'std'])
decade_stats['CV'] = decade_stats['std'] / decade_stats['mean']

# 4.YoY % Change
annual_totals = df['Visitors'].resample('A').sum()
yoy_growth = annual_totals.pct_change()
growth_variance = yoy_growth.var()

# Display Results
print("Global Summary Statistics:")
print(global_stats)
print("\nMonthly Volatility (Sorted by CV):")
print(monthly_stats.sort_values('CV', ascending=False))
# Out:
# Global Summary Statistics:
# mean      2.909738e+05
# median    2.502095e+05
# var       3.219202e+10
# std       1.794213e+05
# skew      5.165533e-01
# Name: Visitors, dtype: float64
#
# Monthly Volatility (Sorted by CV):
#                     mean           var           std        CV
# Date
# December   118335.744681  1.442925e+09  37985.848185  0.321001
# April      209491.425532  3.783578e+09  61510.795223  0.293620
# March      138245.957447  1.614955e+09  40186.498243  0.290688
# November   159619.617021  1.581799e+09  39771.840145  0.249166
# February   109346.765957  7.401736e+08  27206.132097  0.248806
# January    101699.829787  6.047636e+08  24591.942566  0.241809
# May        335809.468085  6.065700e+09  77882.603978  0.231925
# October    324009.382979  5.571179e+09  74640.330693  0.230365
# September  438603.340426  7.389453e+09  85961.925022  0.195990
# June       447375.872340  7.584659e+09  87089.948540  0.194668
# ...

# %% [markdown]
# The distribution of visitors by month shows a clear seasonal pattern. Visitation peaks during the summer months (June through August) and is lowest during the winter months, reflecting typical travel behavior and weather conditions in Yosemite.
#
# The boxplot also indicates that peak months have greater variability, suggesting that visitation during these periods is more sensitive to external factors such as weather or environmental conditions.
#
# Overall, Yosemite visitation follows a strong seasonal pattern with higher and more variable visitor counts during peak months. These patterns provide a baseline for our analysis, as environmental factors may influence when and how often people visit the park.

# %% [markdown]
# ### 3. Temperature Trends
#
# We analyze daily maximum temperature (TMAX) data from NOAA to understand long-term climate patterns in the Yosemite region. Temperature is an important factor because it can influence both air quality and visitor comfort.
#
# This dataset provides high-frequency daily observations, allowing for a more detailed view of variability compared to monthly datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import os

os.makedirs('results', exist_ok=True)

# Load clean data
weather = pd.read_csv('data/02-processed/yosemite_weather_clean.csv')
weather['DATE'] = pd.to_datetime(weather['DATE'])
weather = weather.set_index('DATE')
weather_reset = weather.reset_index()
weather_reset['Month'] = weather_reset['DATE'].dt.month_name()
weather_reset['Year'] = weather_reset['DATE'].dt.year

print(f"Loaded weather data: {weather.shape[0]:,} rows")
print(f"Date range: {weather.index.min().date()} → {weather.index.max().date()}")
print(f"\nTMAX summary:\n{weather['TMAX'].describe().round(2).to_string()}")
print(f"\nPRCP summary:\n{weather['PRCP'].describe().round(2).to_string()}")

# 3.1 — Univariate Distributions: TMAX & Precipitation

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# TMAX distribution
axes[0].hist(weather['TMAX'], bins=35, color='#4C72B0',
             edgecolor='white', linewidth=0.3)
axes[0].axvline(weather['TMAX'].mean(), color='#C44E52', linestyle='--',
                linewidth=1.5, label=f"Mean: {weather['TMAX'].mean():.1f}°F")
axes[0].axvline(weather['TMAX'].quantile(0.95), color='#DD8452', linestyle=':',
                linewidth=1.5, label=f"95th %ile: {weather['TMAX'].quantile(0.95):.1f}°F")
axes[0].set_title("Distribution of Daily Maximum Temperature (TMAX)\n(Yosemite — 1990–2023)",
                  fontsize=11, fontweight='bold')
axes[0].set_xlabel("Daily Max Temperature (°F)")
axes[0].set_ylabel("Count")
axes[0].legend(fontsize=9)
axes[0].spines[["top", "right"]].set_visible(False)

# PRCP distribution non zero days only
prcp_nonzero = weather[weather['PRCP'] > 0]['PRCP']
axes[1].hist(prcp_nonzero, bins=35, color='#4C72B0',
             edgecolor='white', linewidth=0.3)
axes[1].axvline(prcp_nonzero.mean(), color='#C44E52', linestyle='--',
                linewidth=1.5, label=f"Mean (wet days): {prcp_nonzero.mean():.2f} in")
axes[1].set_title("Distribution of Daily Precipitation (PRCP)\n(Non-zero days only — Yosemite, 1990–2023)",
                  fontsize=11, fontweight='bold')
axes[1].set_xlabel("Daily Precipitation (inches)")
axes[1].set_ylabel("Count")
axes[1].legend(fontsize=9)
axes[1].spines[["top", "right"]].set_visible(False)

pct_wet = (weather['PRCP'] > 0).mean() * 100
axes[1].text(0.97, 0.95, f"{pct_wet:.1f}% of days\nhad precipitation",
             transform=axes[1].transAxes, ha='right', va='top',
             fontsize=9, color='gray')

plt.suptitle("Figure 1 — Marginal Distributions of Key Weather Variables",
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('results/fig_weather_marginal_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

print("=== TMAX breakdown (°F) ===")
print(f"Mean:   {weather['TMAX'].mean():.1f}°F")
print(f"Median: {weather['TMAX'].median():.1f}°F")
print(f"Std:    {weather['TMAX'].std():.1f}°F")
print(f"Min:    {weather['TMAX'].min():.1f}°F")
print(f"Max:    {weather['TMAX'].max():.1f}°F")

# 3.2 — Annual Mean TMAX Over Time (Trend)

tmax_yearly = weather['TMAX'].resample('YE').mean().reset_index()
tmax_yearly['Year'] = tmax_yearly['DATE'].dt.year
z = np.polyfit(tmax_yearly['Year'], tmax_yearly['TMAX'], 1)
p = np.poly1d(z)
x_range = np.linspace(tmax_yearly['Year'].min(), tmax_yearly['Year'].max(), 200)

fig, ax = plt.subplots(figsize=(12, 5))
ax.scatter(tmax_yearly['Year'], tmax_yearly['TMAX'],
           s=60, zorder=3, color='#4C72B0', label='Annual Mean TMAX')
ax.plot(x_range, p(x_range), linestyle='--', linewidth=2,
        color='#C44E52', label=f'Trend (slope = {z[0]:+.3f} °F/year)')

warmest = tmax_yearly.loc[tmax_yearly['TMAX'].idxmax()]
coolest = tmax_yearly.loc[tmax_yearly['TMAX'].idxmin()]
ax.annotate(f"{int(warmest['Year'])} ({warmest['TMAX']:.1f}°F)",
            xy=(warmest['Year'], warmest['TMAX']),
            xytext=(warmest['Year'] - 5, warmest['TMAX'] + 0.8),
            arrowprops=dict(arrowstyle='->', color='gray'), fontsize=9)
ax.annotate(f"{int(coolest['Year'])} ({coolest['TMAX']:.1f}°F)",
            xy=(coolest['Year'], coolest['TMAX']),
            xytext=(coolest['Year'] + 1, coolest['TMAX'] - 1.2),
            arrowprops=dict(arrowstyle='->', color='gray'), fontsize=9)

ax.set_title("Figure 2 — Annual Mean Daily Maximum Temperature – Yosemite (1990–2023)",
             fontsize=12, fontweight='bold')
ax.set_xlabel("Year")
ax.set_ylabel("Mean TMAX (°F)")
ax.xaxis.set_major_locator(mticker.MultipleLocator(5))
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:.0f}°F"))
ax.spines[["top", "right"]].set_visible(False)
ax.legend(fontsize=9)
plt.tight_layout()
plt.savefig('results/fig_tmax_annual_trend.png', dpi=150, bbox_inches='tight')
plt.show()

slope_dir = "upward" if z[0] > 0 else "downward"
print(f"Overall trend: {z[0]:+.3f} °F per year ({slope_dir})")
print(f"Warmest year:  {int(warmest['Year'])} ({warmest['TMAX']:.1f}°F)")
print(f"Coolest year:  {int(coolest['Year'])} ({coolest['TMAX']:.1f}°F)")

# 3.3 — Seasonal Distribution of TMAX by Month

month_order = ['January','February','March','April','May','June',
               'July','August','September','October','November','December']

fig, ax = plt.subplots(figsize=(14, 5))
sns.boxplot(x='Month', y='TMAX', data=weather_reset,
            order=month_order, palette='coolwarm',
            linewidth=0.8, ax=ax)
ax.set_title("Figure 3 — Seasonal Distribution of Daily Maximum Temperature by Month\n(Yosemite — 1990–2023)",
             fontsize=12, fontweight='bold')
ax.set_xlabel("Month")
ax.set_ylabel("Daily Max Temperature (°F)")
ax.tick_params(axis='x', rotation=45)
ax.spines[["top", "right"]].set_visible(False)
plt.tight_layout()
plt.savefig('results/fig_tmax_monthly_boxplot.png', dpi=150, bbox_inches='tight')
plt.show()

print("=== Average TMAX by Month ===")
print(weather_reset.groupby('Month')['TMAX']
      .mean().reindex(month_order).round(1).to_string())

# 3.4 — Mean TMAX by Decade

weather_reset['Decade'] = (weather_reset['Year'] // 10) * 10
decade_means = weather_reset.groupby('Decade')['TMAX'].mean().reset_index()
decade_means['Label'] = decade_means['Decade'].astype(str) + 's'

fig, ax = plt.subplots(figsize=(8, 5))
colors = ['#4C72B0', '#55A868', '#C44E52', '#DD8452']
bars = ax.bar(decade_means['Label'], decade_means['TMAX'],
              color=colors[:len(decade_means)], edgecolor='white',
              linewidth=0.5, width=0.6)
for bar, val in zip(bars, decade_means['TMAX']):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.15,
            f'{val:.1f}°F', ha='center', va='bottom', fontsize=10, fontweight='bold')

ax.set_title("Figure 4 — Mean Daily Maximum Temperature by Decade\n(Yosemite — 1990–2023)",
             fontsize=12, fontweight='bold')
ax.set_xlabel("Decade")
ax.set_ylabel("Mean TMAX (°F)")
ax.set_ylim(bottom=decade_means['TMAX'].min() - 3)
ax.spines[["top", "right"]].set_visible(False)
plt.tight_layout()
plt.savefig('results/fig_tmax_by_decade.png', dpi=150, bbox_inches='tight')
plt.show()

print("=== Mean TMAX by Decade ===")
print(decade_means[['Label','TMAX']].round(2).to_string(index=False))
# Out:
# Loaded weather data: 9,748 rows
# Date range: 1990-01-01 → 2023-11-29
#
# TMAX summary:
# count    9748.00
# mean       67.82
# std        17.45
# min        21.00
# 25%        53.00
# 50%        68.00
# 75%        84.00
# max       104.00
#
# PRCP summary:
# count    9748.00
# mean        0.10
# std         0.35
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         5.43
# === TMAX breakdown (°F) ===
# Mean:   67.8°F
# Median: 68.0°F
# Std:    17.5°F
# Min:    21.0°F
# Max:    104.0°F
# Overall trend: +0.011 °F per year (upward)
# Warmest year:  2007 (76.6°F)
# Coolest year:  2022 (57.8°F)
# /tmp/ipykernel_19467/2026281942.py:59: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   tmax_yearly = weather['TMAX'].resample('Y').mean().reset_index()
# === Average TMAX by Month ===
# Month
# January      48.3
# February     51.7
# March        57.1
# April        63.7
# May          71.3
# ...

# %% [markdown]
# ---
#
# **3.1 — Univariate Distributions: TMAX & Precipitation**
#
# Before looking at the relationship between our variables, we first wanted to examine the individual distributions of our two key weather variables: daily maximum temperature (TMAX) and total daily precipitation (PRCP).
#
# TMAX appears to be approximately normally distributed, with a mean of 67.8°F and a median of 68.0°F. Because these two values are very close to each other, this tells us that the data is not heavily skewed in either direction. The standard deviation of 17.5°F reflects the wide range of temperatures that Yosemite experiences across different seasons, with recorded values ranging from a minimum of 21.0°F all the way up to a maximum of 104.0°F.
#
# For precipitation, the data is heavily right skewed. The median daily precipitation is 0.00 inches, meaning that on most days throughout the study period there was no recorded precipitation at all. On the days that did see rain or snow, amounts were generally small, though the highest single day total reached 5.43 inches. This kind of distribution is expected for Yosemite given its Mediterranean climate, where rainfall is mostly concentrated in the winter months and is rare during the summer. Because of this skew, we only plot non-zero precipitation days in the distribution figure and will treat precipitation as a control variable in our later regression analysis rather than a primary focus.
#
# ---
#
# **3.2 — Annual Mean TMAX Over Time**
#
# To understand whether temperatures in the Yosemite region have changed over time, we calculated the annual mean TMAX for each year from 1990 to 2023 and fit a linear trend line to the data.
#
# The overall trend shows a slight increase of +0.011°F per year, which suggests a modest long term warming trend in the region over the 33 year study period. While this slope is small, it is consistent with the broader climate trends that have been documented in the Sierra Nevada. The warmest year in our dataset was 2007 with an annual mean of 76.6°F, while the coolest year was 2022 at 57.8°F. The roughly 19°F gap between these two years highlights how much year to year variability exists in the data relative to the overall trend. This is important for our analysis because it means that controlling for temperature is necessary when examining our main research question, otherwise we risk confusing temperature driven seasonal patterns with the effect of AQI on visitor counts.
#
# ---
#
# **3.3 — Seasonal Distribution of TMAX by Month**
#
# The monthly boxplot shows a clear and expected seasonal pattern in daily maximum temperatures at Yosemite. Temperatures are at their lowest in December and January, with monthly averages of 46.7°F and 48.3°F respectively, and gradually increase through the spring before peaking in July and August at 89.5°F and 89.4°F. After the summer peak, temperatures decline steadily through the fall months.
#
# One thing worth noting is that the spread of values is wider during the shoulder months like April, May, September, and October, which suggests that temperatures during these transitional periods are more variable from day to day. Winter months on the other hand tend to have tighter distributions, reflecting more consistently cold conditions. This seasonal pattern is directly relevant to our research question because park visitation also follows a seasonal pattern, peaking in the summer. This means that any observed relationship between temperature and visitation could simply be reflecting this shared seasonal trend rather than a true causal effect, which is why we include temperature as a control variable in our model.
#
# ---
#
# **3.4 — Mean TMAX by Decade**
#
# To get a broader picture of how temperatures have shifted over the study period, we also looked at mean TMAX broken down by decade. The average daily maximum temperature increased from 67.1°F in the 1990s to 68.2°F in the 2000s and 68.5°F in the 2010s, representing a cumulative increase of about 1.5°F over 30 years. The 2020s show a lower average of 67.2°F, however this figure should be interpreted cautiously because it only includes data from 2020 through part of 2023, and the unusually cool 2022 pulls the average down considerably.
#
# Overall these results are consistent with the slight upward trend seen in Figure 2 and suggest a modest but real warming pattern across the study period. Because temperature can independently influence both air quality and visitor behavior, these findings reinforce why it is important to control for TMAX in our regression analysis when examining the relationship between AQI and daily visitor counts at Yosemite National Park.

# %% [markdown]
# ### 4. Precipitation Trends
#
# We analyze total precipitation (PRCP) data from NOAA to examine rainfall patterns in Yosemite. Precipitation is important because it affects environmental conditions such as wildfire risk, trail accessibility, and overall visitor experience.
#
# Like temperature, this dataset provides daily observations, allowing us to capture detailed variability over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# load raw data
path = "https://raw.githubusercontent.com/COGS108/Group046_WI26/ria/data/00-raw/raw_precipitation_data.csv"
df = pd.read_csv(path)

# filter Yosemite station
precip = df[df['STATION_NAME'].str.contains('YOSEMITE', na=False)].copy()

# correct date conversion
precip['Date'] = pd.to_datetime(precip['DATE'], format='%Y%m%d')

# rename precipitation column
precip.rename(columns={'PRCP': 'Precipitation'}, inplace=True)

# Replace missing values
precip['Precipitation'] = precip['Precipitation'].replace(-9999, np.nan)
precip = precip.dropna(subset=['Precipitation'])

# extract year after fixing date
precip['Year'] = precip['Date'].dt.year

# aggregate to annual totals
annual_total = (
    precip
    .groupby('Year')['Precipitation']
    .sum()
    .reset_index()
)

# fit linear trend line
z = np.polyfit(annual_total['Year'],
               annual_total['Precipitation'], 1)
p = np.poly1d(z)

# create figure
fig, ax = plt.subplots(figsize=(12, 5))

# scatter plot
ax.scatter(
    annual_total['Year'],
    annual_total['Precipitation'],
    s=60,
    zorder=3,
    label='Annual Total Precipitation'
)

# trend line
x_range = np.linspace(
    annual_total['Year'].min(),
    annual_total['Year'].max(),
    200
)

ax.plot(
    x_range,
    p(x_range),
    linestyle='--',
    linewidth=2,
    label=f'Trend (slope={z[0]:.2f} inches/year)'
)

# annotate wettest year
wettest = annual_total.loc[
    annual_total['Precipitation'].idxmax()
]

ax.annotate(
    f"{int(wettest['Year'])}\n({wettest['Precipitation']:.1f} in)",
    xy=(wettest['Year'], wettest['Precipitation']),
    xytext=(wettest['Year'] - 3,
            wettest['Precipitation'] + 5),
    arrowprops=dict(arrowstyle='->')
)

# labels & formatting
ax.set_xlabel('Year')
ax.set_ylabel('Total Annual Precipitation (inches)')
ax.set_title('Annual Total Precipitation - Yosemite (1990–2025)',
             fontweight='bold')

ax.xaxis.set_major_locator(ticker.MultipleLocator(5))

plt.tight_layout()
plt.show()

# print summary
driest = annual_total.loc[
    annual_total['Precipitation'].idxmin()
]

print(f"Overall trend: {z[0]:+.3f} inches per year")
print(f"Wettest year: {int(wettest['Year'])} "
      f"({wettest['Precipitation']:.1f} inches)")
print(f"Driest year: {int(driest['Year'])} "
      f"({driest['Precipitation']:.1f} inches)")
# Out:
# Overall trend: -0.411 inches per year
# Wettest year: 1996 (62.7 inches)
# Driest year: 2007 (2.3 inches)

# %% [markdown]
# The trend line slope tells us the average annual change in total precipitation over the
# 35 year study period. A negative slope indicates that Yosemite has experienced a
# slight decrease in annual precipitation from 1990 to 2025. These results are not
# surprising to see, especially with the issues of climate change arising. Spike years,
# such as the wettest year in the dataset, possibly relate to extreme storm events or
# strong atmospheric river systems, whereas the driest year reflects periods of drought
# or low snowpack accumulation. These shifts in data, combined with the long-term
# trend, explains the importance of monitoring precipitation for park management. This
# is because variability in precipitation can affect water resources, snowpack levels, trail
# safety, and flood/landslide risk. Understanding these patterns are essential for
# anticipating climate impacts on both the park’s natural systems and visitor
# experiences.

# %% [markdown]
# ### Summary of EDA Findings
#
# Across all datasets, we observe that environmental conditions in Yosemite are dynamic:
#
# - Air quality (ozone) shows variability with occasional extreme years
# - Visitor counts follow strong seasonal patterns
# - Temperature exhibits a slight upward trend over time
# - Precipitation is highly variable with no clear long-term pattern
#
# These findings suggest that environmental factors may influence visitor behavior, but the relationships are not immediately clear from visualization alone. This motivates further analysis in the following sections.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - **A.1 Informed consent**: Our project utilizes secondary data from trailhead sensors and EPA monitors. The data is collected at an aggregate level with no Personally Identifiable Information (PII). We treat missing monitor days as genuinely missing rather than 'Good' air quality.
#
#  - [X] **A.2 Collection bias**: We acknowledge that activity outside official park hours or uncharted areas of the park is not captured. We focus on consistent data sources and specify temporal scope to avoid confounding variables.
#  - [X] **A.3 Limit PII exposure**: All data is anonymized aggregate counts. We limit the dataset to only variables necessary to address the research question.
#
#  - **A.4 Downstream bias mitigation**: Results cannot be used to infer behavioral differences among specific groups of people.
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Data is stored on password-protected devices and a private GitHub repository accessible only by team members.
#  - [ ] **B.2 Right to be forgotten**: Data is fully anonymized; no individual records exist to remove.
#  - [ ] **B.3 Data retention plan**: Datasets will be deleted after the course project unless needed for academic purposes.
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: We cannot account for individual visitor motivations, health conditions, or socioeconomic constraints. We ground interpretations in established literature.
#  - [ ] **C.2 Dataset bias**: Spatial mismatch between the Yosemite Village EPA monitor and high-elevation trailheads may not reflect localized smoke patterns. We mitigate this with temperature and precipitation control variables.
#  - [ ] **C.3 Honest representation**: Results will be conveyed as associations, not causal relationships. All figures will have clearly labeled axes and 95% confidence intervals.
#  - [ ] **C.4 Privacy in analysis**: Only aggregated daily-level summaries are reported.
#  - [ ] **C.5 Auditability**: Full workflow is maintained in a GitHub repository with version control.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Trailhead counts may proxy for socioeconomic status. We will acknowledge that the average behavioral response may be skewed toward visitors with more autonomy to reschedule trips.
#  - [X] **D.2 Fairness across groups**: AQI disproportionately impacts vulnerable groups. Stable attendance numbers do not imply all visitor groups are equally protected.
#  - [X] **D.3 Metric selection**: Metrics are framed as indicators of recreational demand during environmental hazards, not holistic measures of trail importance.
#  - [X] **D.4 Explainability**: Multiple linear regression coefficients and 95% confidence intervals will be reported to ensure interpretable results for stakeholders.
#  - [X] **D.5 Communicate limitations**: Study is restricted to Yosemite, 1990–2023, and findings may not generalize to other parks. The model identifies associations, not causation.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: We will audit predictions against actual sensor counts to detect concept drift over time.
#  - [X] **E.2 Redress**: If outputs lead to societal harm or resource misallocation, we will review and correct the model.
#  - [X] **E.3 Roll back**: Git version control allows rollback to any stable state if a prediction creates a problematic feedback cycle.
#  - [X] **E.4 Unintended use**: We will clearly communicate that the model identifies associations rather than causal relationships to prevent misuse.

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
